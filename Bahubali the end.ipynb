# %%
#Bahubali -The beginning

'''
Docstring:

     Introduction:
     
     Amarendra bahubali was born an orphan; his father king vikramdeva had died before he was born and also his mother died giving birth to him.
     Lord bijjala deva, vikramadevas brother and the next member of the Mahishmathi royal family denied throne due to his cunning and deranged nature. 
     Bijjaladeva's wife,Lady Sivagami, seized power as interim queen, intending to raise both Bhalla(shivgami son)and Bahubali inorder to choose the right heir. 
     Bhalla and Bahubali were both raised equally and rigorously trained in the art of warfare, mathematics, administration, logic and many.
     Bijjaladeva the cunning is eager to make her son the next king even because of his father even bhalla developed cruelty and recklessness to take the throne.
     Shivagami an acting monarch is confused in deciding the rightful heir to the throne. 
     Theres a situation where leader of one of the largest tribe Inkoshi(kalakeya) declares war against mahishmathi. 
     shivagami decides whoever kills Inkoshi would be the new worthy king, Bijjaladeva secretly makes sure that bhalla has more weapons and men.'''
 

print("""🐎🐘🐪
 #     #    #    ######  
 #  #  #   # #   #     # 
 #  #  #  #   #  #     # 
 #  #  # #     # ######  
 #  #  # ####### #   #   
 #  #  # #     # #    #  
  ## ##  #     # #     # 
                         

🐎🐘🐪""")   

#choose you want to play the game or not:

#Applying the defined prompt function 

Mahishmathi = input(prompt="Bahubali is ready , would you like to start the war? yes/no: \n")

#conditional statements with if, else and elif

if 'yes' in Mahishmathi.lower() or 'y' in Mahishmathi.lower():
    print("Jai Mahishmathi!🎠 \n")
    
elif Mahishmathi.lower() == "no":
    print("That's so sad , you are under kalakeyas rule/n.")
    
else:
    print("you are out of mahishmathi🐪\n.")

#nested if condition for weapon:

weapon = input(prompt="Would you like to choose the weapon? Type yes or no:\n ")

if weapon.lower() == "yes":
    weapon = input(prompt="\nYou are in war ground, would you like to start the war with arrows/sword.\n\t")
    if weapon.lower() == "arrows":
        print("\nThats a great start of war, it killed many of kalakeyas army🏹🏹🏹.\n")
    elif weapon == "sword":
        print("Thats really bad idea , You cant simply swing the swords in air when war starts⚔️⚔️⚔️.\n")
        stage(1)
    else:
        print("Run back you are not a warrior⚠️.\n")
        
else:
    print("looser! start the game again\n")
    
print("""Bahubali spirit up in finishing up this to get a magic route to kalakeya army""")

# importing Random function
import random

# The guess function  

Magic_Route = random.randint(1,10) 


# looping a while function to Magic_Route
while True:
    Route = input(prompt='\n What is your guess (1-10)?\n> ')
    
    
    Route = int(Route)
    
    # Conditional statement for the input
    if Route == Magic_Route:
        print("\nYou got the route!")
        break

    elif  Route != Magic_Route:
        print(f"\nThis route is incorrect. Please try other route.")

    # if there is something mistake error message will display
    else:
        print("\n Go back.")

    
#The option plane is for promotions of our gaming corporation

Choose_the_ride = input(prompt="\nWhat kind of ride you want under bahubali army? plane/horse?:\n ")

if 'horse' in Choose_the_ride:
    print("\nyour cavalry is ready to run on grounds......jai mahishmathi!🐎🐎🐎\n")

elif 'plane' in Choose_the_ride:
    print("\nSoo sorry we are not that globalized to get a plane in this historic game. Download other games under our gaming corporation\nwhich will be available on Play store or app store.Thank you🎮🚁\n")               
    
print("""###\nBhalla🤴🏽 got enough army and weapons to strike the kalakeyas army
.\n You need magic weapon which is avaialble in war ground find it.\nplay this changing pillar game to get the magic weapon\n fastup you have no time. \nKalakeyas are rushing.\n
      power-up your horse\n###""")

#Random infinite guessing option:
import random
n=20
magic_pillar = int(n * random.random()) + 1

#Inputing number of guesses to the random function
guess = 0
while guess != magic_pillar:
    guess = int(input(prompt="New pillar: (Choose a number between 1 to 20)"))
    if guess > 0:
        if guess > magic_pillar:
            print("Number too large✨ (Choose small number)")
        elif guess < magic_pillar:
            print("Number too small✨ (Choose large number)")

#using the break function to terminate the current loop            
    else:
        print("\nSorry that you are giving up!\n")
        break
        
else:
    print("\nCongratulations. Bahubali✨✨✨\n")
    
print("""\n###You got in to a situation where you can strike inkoshi👹easily. \n and on the other side hostages from your kingdom were kidnapped by kalakeya army and are tortured.\n Think like a king and choose the option.\n###""")

#using the time function retrieves the current time
import time

#defining function to block the code until it gets called

def kalakeya_trick():

    print("\nyou have a chance to use the weapon against inkoshi👹🗡️\n")
    print("\non the other side you have hostages torturing by kalakeya army\n")
    print("\nwhat would you do?\n")
    print("\n1). Use weapon against inkoshi and end the war🗡️\n")
    print("\n2). Save your hostages from kalakeya army \n")
 
    answer = input(prompt="\nwhich of the options you want to choose? 1/2\n")

#conditional statements with if, else and elif

    if answer == "1":
        print("\nYou are not the rightful heir , \nking is the one who dies for people not for the throne.\n")
        time.sleep(4)
        kalakeya_trick()
    elif answer =="2":
        print("\n Thats great decison.\n Proceed the war , still weapon is in your hands kill the kalakeya leader👹\n.")
    else:
        print("\nDo you want to try again.\n")
        kalakeya_trick()
        

kalakeya_trick()

print("###\nYou are facing inkoshi. you have to strike on the weak point of inkoshi👹\n. When kalakeyas watch their leader dying they disperse and run back.\n You got a chance Bahubali🤴, \nStrike your magic weapon!\nkeep in mind you have only four chances to strike.\nOtherwise you will loose.🎠🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎🐎\n###")

#random input with limited chances:

import random

weak_point = random.randint(1,10)
guess_the_weak_point = 4

while guess_the_weak_point> 0:
    first_strike = int(input(prompt="\nGuess the weak point you should strike your sword on inkoshi?👹⚔️(Choose number between 1 to 10:)\n"))
    
    if first_strike == weak_point:
        print("\nYou won! Amarendra Bahubali you are the righful heir of Mahishmathi👑.\n")
        break
        
    elif first_strike != weak_point:
        print("\nThats incorrect strike, please strike again.⚔️\n")
        guess_the_weak_point -= 1
    else:
        print("\nSomething went wrong.\n")
        
print(f"""\nThe number was {weak_point}""")

#inputing random function
import random 

#random choices inputed to random function

Greetings = ['Great', 'The_king', 'Ruler_of_Mahishmathi', 'The_leader']

value = random.choice(Greetings)
print(value + '\nBahubali!' )


print("""(👑
                                                                                 
 _______  _______  _______  _______  _______  _______  _______  _______  _______ 
|\     /||\     /||\     /||\     /||\     /||\     /||\     /||\     /||\     /|
| +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ |
| |   | || |   | || |   | || |   | || |   | || |   | || |   | || |   | || |   | |
| |B  | || |A  | || |H  | || |U  | || |B  | || |H  | || |A  | || |L  | || |I  | |
| +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ || +---+ |
|/_____\||/_____\||/_____\||/_____\||/_____\||/_____\||/_____\||/_____\||/_____\|
                                                                                 
👑)                                                
                                                                                                                                                      
""")

print("###Please do watch this epic movie which is available in two parts- \nBahubali the beginning and conclusion.\n Thank you for playing game.\n###")
# Out:
# 🐎🐘🐪
#  #     #    #    ######
#  #  #  #   # #   #     #
#  #  #  #  #   #  #     #
#  #  #  # #     # ######
#  #  #  # ####### #   #
#  #  #  # #     # #    #
#   ## ##  #     # #     #
#
#
# 🐎🐘🐪
# Bahubali is ready , would you like to start the war? yes/no:
# yes
# Jai Mahishmathi!🎠
#
# Would you like to choose the weapon? Type yes or no:
#  yes
#
# You are in war ground, would you like to start the war with arrows/sword.
# 	arrows
#
# Thats a great start of war, it killed many of kalakeyas army🏹🏹🏹.
#
# Bahubali spirit up in finishing up this to get a magic route to kalakeya army
#
#  What is your guess (1-10)?
# > 1
#
# This route is incorrect. Please try other route.
#
#  What is your guess (1-10)?
# > 2
#
# You got the route!
#
# What kind of ride you want under bahubali army? plane/horse?:
#  plane
#
# Soo sorry we are not that globalized to get a plane in this historic game. Download other games under our gaming corporation
# ...
